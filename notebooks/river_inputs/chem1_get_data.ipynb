# %%
import matplotlib.pyplot as plt
import nivapy3 as nivapy
import pandas as pd
import seaborn as sns
import os
import re

from datetime import datetime

plt.style.use("ggplot")

# %% [markdown]
# # Get water chemistry data from NIVA's database
#
# This notebook retrieves, filters, and exports water chemistry and station metadata from NIVA’s database using the `nivapy3` Python library. It is intended to be run in NIVA’s JupyterLab-based research environment.
#
# ### How to run the analysis?
# 1. Clone the AquaINFRA GitHub repo or copy the notebook to your environment in NIVA's JupyterHub.
# 2. Make sure the following dependencies are installed in the environment: pandas, nivapy3, matplotlib, seaborn, os
# 3. Login with Oracle username and password.
# 4. Define the project, stations, and parameters of interest.
# 5. Run all cells sequentially.
#
# ### Which programming languages are used?
# - Python
#
# ### How does the workflow look like?
# 1. Database connection
# 2. Project selection by filtering project names
# 3. Station retrieval and filtering
# 4. Interactive map visualization of selected stations
# 5. Water chemistry parameter discovery for a given date range
# 6. Water chemistry data retrieval
# 7. Rename parameters to avoid ambiguity
# 8. Export of station metadata and water chemistry to CSV files
#
# ### Which functions are used and how are they connected?
# - `nivapy.da.connect()` – Connects to the database
# - `nivapy.da.select_ndb_projects()` – Fetches all projects
# - `nivapy.da.select_ndb_project_stations()` – Retrieves stations for a selected project
# - `nivapy.spatial.quickmap()` – Visualizes stations on a map
# - `nivapy.da.select_ndb_station_parameters()` – Lists available chemistry parameters for given stations and time span
# - `nivapy.da.select_ndb_water_chemistry()` – Fetches the water chemistry data
#
# ### Anything else needed to run the analysis?
# - Access to the Oracle database and user credentials
# - Oracle client libraries installed in the environment
# - A working clone or path reference to the `nivapy3` library [https://github.com/NIVANorge/nivapy3](https://github.com/NIVANorge/nivapy3)
#
# **Note**: For internal use only. External users may need adaptations due to restricted database access.

# %% [markdown]
# ## 0. User inputs

# %%
# Define project name
project_name = "Elveovervåkingsprogrammet"

# Define stations of interest
stations_to_keep = ["Drammenselva", "Numedalslågen v/E18", "Glomma, Sarpsfossen"]

# Mapping full station names to simplified river names
river_mapper = {
    "Drammenselva": "Drammenselva",
    "Numedalslågen v/E18": "Numedalslagen",
    "Glomma, Sarpsfossen": "Glomma"
}

# Period of interest
st_dt = "1980-01-01"
end_dt = "2024-08-31"

# Parameters of interest
par_list = ["NH4-N", "NO3-N", "TOTN_EF_usikker", "SiO2", "Si", "TOC", "TOTN", 
            "TOTP", "TOTP_P", "DOC", "POC", "STS", "TSM", "PO4-P", "TOTP/F", 
            "Farge", "UV-Abs. 410nm", "UV-Abs. 254nm"]

# Mapping parameter names for consistency 
parameter_name_map = {
    "Farge": "Color",
    "NH4-N": "NH4-N", 
    "NO3-N": "NO3-N", 
    "PO4-P": "TRP", 
    "TOTP/F": "TDP", 
    "TOTP_P": "PP",
    "STS": "SPM", 
    "UV-Abs. 254nm": "UV_Abs_254nm",
    "UV-Abs. 410nm": "UV_Abs_410nm"
}

unit_map = {
    "mg/L C": "mg/l C"
}


# Drop irrelevant columns (depth is always zero)
cols_to_drop = ["depth1", "depth2"]

# Where to save data
base_dir = '../../data/river/water_chemistry/raw/' # Define base directory path
os.makedirs(base_dir, exist_ok=True) # Create directory (and parents) if it doesn't exist
today_str = datetime.today().strftime('%d-%m-%Y')  # For file naming

par_units_fpath = '../../data/river/water_chemistry/raw/water_chemistry_parameters_units.csv'

# %% [markdown]
# ## 1. Login

# %%
# Login with Oracle username and password
eng = nivapy.da.connect()
# Out:
# Username:  ········
# Password:  ········
# Connection successful.

# %% [markdown]
# ## 2. Get stations

# %%
# Get all projects in nivadatabase
proj_df = nivapy.da.select_ndb_projects(eng)
proj_df.head()
# Out:
# 1536 projects in the NIVADATABASE.
#    project_id     project_name project_description
# 0           1              xxx                None
# 1          55  PARCOM_Aquateam                None
# 2          56      PARCOM_NIVA                None
# 3          58          MAR_BOK             Fagdata
# 4          59          MAR_IMA             Fagdata

# %%
# Filter to just the project 
proj_df = proj_df.query(
    "project_name.str.contains(@project_name)", engine="python"
)
proj_df
# Out:
#      project_id               project_name  \
# 995       10306  Elveovervåkingsprogrammet
#
#                                    project_description
# 995  Etterfølgeren til RID. Overvåking av tilførsle...

# %%
stn_df = nivapy.da.select_ndb_stations(eng)
stn_df.head()
# Out:
# 30507 stations in the NIVADATABASE.
#    station_id station_code   station_name station_type   latitude  longitude
# 0        3561      BUSEDRA   Drammenselva          Elv  59.753992  10.009029
# 1        3562      FINEALT      Altaelva.          Elv  69.901142  23.287058
# 2        3563      NOREVEF        Vefsna.          Elv  65.749464  13.239104
# 3        3564      ROGEORR       Orreelva          Elv  58.731430   5.529362
# 4        3565      ROGESUL  Suldalslågen.          Elv  59.482215   6.259855

# %%
# Select stations for the specific project
stn_df = nivapy.da.select_ndb_project_stations(proj_df, eng, drop_dups=True)
stn_df.head()
# Out:
#    station_id station_code         station_name station_type  longitude  \
# 0       40352      BUSEDRA         Drammenselva          Elv  10.007898
# 1       40353          SKI           Skienselva          Elv   9.606396
# 2       40354         OTR2      Otra v/Skråstad          Elv   7.958165
# 3       40355         NUM1  Numedalslågen v/E18          Elv  10.070949
# 4       40356      CGL SAR  Glomma, Sarpsfossen          Elv  11.134112
#
#     latitude
# 0  59.752576
# 1  59.203230
# 2  58.184772
# 3  59.101283
# 4  59.279802

# %%
# Show stations
nivapy.spatial.quickmap(
    stn_df, cluster=True, aerial_imagery=True, kartverket=True, popup="station_code"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a3589e526b737c956970b078f2b0372 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a3589e526b737c956970b078f2b0372&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a3589e526b737c956970b078f2b0372 = L.map(
#                 &quot;map_3a3589e526b737c956970b078f2b0372&quot;,
#                 {
#                     center: [62.65735181285715, 12.30907653857143],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_126b18b8ec1766e70fdbf6673c25512a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_126b18b8ec1766e70fdbf6673c25512a.addTo(map_3a3589e526b737c956970b078f2b0372);
#
#
#             var tile_layer_c46b500a2c382562ebb0beb622c91565 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: [&quot;mt0&quot;, &quot;mt1&quot;, &quot;mt2&quot;, &quot;mt3&quot;], &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c46b500a2c382562ebb0beb622c91565.addTo(map_3a3589e526b737c956970b078f2b0372);
#
#
#             var tile_layer_42575cd385a1113020a586a8843f2391 = L.tileLayer(
#                 &quot;https://opencache.statkart.no/gatekeeper/gk/gk.open_gmaps?layers=topo4\u0026zoom={z}\u0026x={x}\u0026y={y}&quot;,
#                 {&quot;attribution&quot;: &quot;karkverket&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_42575cd385a1113020a586a8843f2391.addTo(map_3a3589e526b737c956970b078f2b0372);
#
#
#             var feature_group_c7bbfddb247cb6077d96530d60e64ff0 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_cluster_520dc0358a84b0a687fe4193d6be40b3 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8c6bf9bc5981e96b4000e5b76f4ae90a = L.marker(
#                 [59.75257593, 10.00789751],
#                 {}
#             ).addTo(marker_cluster_520dc0358a84b0a687fe4193d6be40b3);
#
#
#         var popup_4310a1d46ebc980f11761db025156c16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96f7e4790dc868d54bfffc089e0058c9 = $(`&lt;div id=&quot;html_96f7e4790dc868d54bfffc089e0058c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BUSEDRA&lt;/div&gt;`)[0];
#                 popup_4310a1d46ebc980f11761db025156c16.setContent(html_96f7e4790dc868d54bfffc089e0058c9);
#
#
#
#         marker_8c6bf9bc5981e96b4000e5b76f4ae90a.bindPopup(popup_4310a1d46ebc980f11761db025156c16)
#         ;
#
#
#
#
#             var marker_3c41cb684ebbf4bd8a9afdbe148fe028 = L.marker(
#                 [59.20322999, 9.60639554],
#                 {}
#             ).addTo(marker_cluster_520dc0358a84b0a687fe4193d6be40b3);
#
#
#         var popup_e40f382566265808c5933730b2b4142a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_831bbec2f068c41a9d74990ee15d0181 = $(`&lt;div id=&quot;html_831bbec2f068c41a9d74990ee15d0181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SKI&lt;/div&gt;`)[0];
#                 popup_e40f382566265808c5933730b2b4142a.setContent(html_831bbec2f068c41a9d74990ee15d0181);
#
#
#
#         marker_3c41cb684ebbf4bd8a9afdbe148fe028.bindPopup(popup_e40f382566265808c5933730b2b4142a)
#         ;
#
#
#
#
#             var marker_071e62183d42bd8bc6de5f81484a778f = L.marker(
#                 [58.18477182, 7.95816506],
#                 {}
#             ).addTo(marker_cluster_520dc0358a84b0a687fe4193d6be40b3);
#
#
#         var popup_2827db4de5eb52579dcc762ba4fe1c9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d910990ca9d5c70b2316a83ea665ffef = $(`&lt;div id=&quot;html_d910990ca9d5c70b2316a83ea665ffef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OTR2&lt;/div&gt;`)[0];
#                 popup_2827db4de5eb52579

# %%
# Select the stations of interest
sel_stn_df = stn_df[stn_df['station_name'].isin(stations_to_keep)]

# Show stations
nivapy.spatial.quickmap(
    sel_stn_df, cluster=True, aerial_imagery=True, kartverket=True, popup="station_code"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a32dd5e2d487a385362712ef46c4c2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a32dd5e2d487a385362712ef46c4c2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a32dd5e2d487a385362712ef46c4c2ce = L.map(
#                 &quot;map_a32dd5e2d487a385362712ef46c4c2ce&quot;,
#                 {
#                     center: [59.377886983333326, 10.404319266666667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f2d2ccee52f9d59379b56c9090d1b6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5f2d2ccee52f9d59379b56c9090d1b6a.addTo(map_a32dd5e2d487a385362712ef46c4c2ce);
#
#
#             var tile_layer_65183eed6585078de7cd76bf8a6f9c1b = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: [&quot;mt0&quot;, &quot;mt1&quot;, &quot;mt2&quot;, &quot;mt3&quot;], &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_65183eed6585078de7cd76bf8a6f9c1b.addTo(map_a32dd5e2d487a385362712ef46c4c2ce);
#
#
#             var tile_layer_37a478f779b68dd8f38c85ace30b1d67 = L.tileLayer(
#                 &quot;https://opencache.statkart.no/gatekeeper/gk/gk.open_gmaps?layers=topo4\u0026zoom={z}\u0026x={x}\u0026y={y}&quot;,
#                 {&quot;attribution&quot;: &quot;karkverket&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37a478f779b68dd8f38c85ace30b1d67.addTo(map_a32dd5e2d487a385362712ef46c4c2ce);
#
#
#             var feature_group_a9deebf8378da3d32d046e791fa2f177 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_cluster_a2a2b4a269408896109cb54bfefa715a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7d381fce6865428e6e02b69da9016cdd = L.marker(
#                 [59.75257593, 10.00789751],
#                 {}
#             ).addTo(marker_cluster_a2a2b4a269408896109cb54bfefa715a);
#
#
#         var popup_b2cd6cba8ee19cd23f529fda6f8fd3c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_017f6fc1aa5d651eb291e9f74371abe8 = $(`&lt;div id=&quot;html_017f6fc1aa5d651eb291e9f74371abe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BUSEDRA&lt;/div&gt;`)[0];
#                 popup_b2cd6cba8ee19cd23f529fda6f8fd3c2.setContent(html_017f6fc1aa5d651eb291e9f74371abe8);
#
#
#
#         marker_7d381fce6865428e6e02b69da9016cdd.bindPopup(popup_b2cd6cba8ee19cd23f529fda6f8fd3c2)
#         ;
#
#
#
#
#             var marker_237548d5893278a7d1a8625af58b5a41 = L.marker(
#                 [59.10128295, 10.07094871],
#                 {}
#             ).addTo(marker_cluster_a2a2b4a269408896109cb54bfefa715a);
#
#
#         var popup_7010e40153c721f478d86e6e0ffb7fd5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2480c9b03996417c64b806efa94032cb = $(`&lt;div id=&quot;html_2480c9b03996417c64b806efa94032cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NUM1&lt;/div&gt;`)[0];
#                 popup_7010e40153c721f478d86e6e0ffb7fd5.setContent(html_2480c9b03996417c64b806efa94032cb);
#
#
#
#         marker_237548d5893278a7d1a8625af58b5a41.bindPopup(popup_7010e40153c721f478d86e6e0ffb7fd5)
#         ;
#
#
#
#
#             var marker_09c435e58d138a29b6365828eed2f536 = L.marker(
#                 [59.27980207, 11.13411158],
#                 {}
#             ).addTo(marker_cluster_a2a2b4a269408896109cb54bfefa715a);
#
#
#         var popup_152b5a85cdb580c15710b1402086e13d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e340e7794c9c65da675b8a366468ba3 = $(`&lt;div id=&quot;html_9e340e7794c9c65da675b8a366468ba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CGL SAR&lt;/div&gt;`)[0];
#                 popup_152b5a85c

# %%
# Save sites metadata
for full_station_name, simple_river_name in river_mapper.items():
    river_meta_df = sel_stn_df[sel_stn_df['station_name'] == full_station_name]
    
    if not river_meta_df.empty:
        filename = f'water_chem_{simple_river_name}_metadata_{today_str}.csv'
        filepath = os.path.join(base_dir, filename)
        river_meta_df.to_csv(filepath, index=False)
        print(f'Saved {filepath}')
    else:
        print(f'No data for station: {full_station_name}')
# Out:
# Saved ../../data/river/water_chemistry/raw/water_chem_Drammenselva_metadata_18-06-2025.csv
# Saved ../../data/river/water_chemistry/raw/water_chem_Numedalslagen_metadata_18-06-2025.csv
# Saved ../../data/river/water_chemistry/raw/water_chem_Glomma_metadata_18-06-2025.csv

# %% [markdown]
# ## 3. Get parameters of interest

# %%
# Find water chemistry parameters available for a set of stations within a period of interest
par_df = nivapy.da.select_ndb_station_parameters(sel_stn_df, st_dt, end_dt, eng)

# Filter to parameters of interest
par_df = par_df.query("parameter_name in @par_list")
par_df = par_df[par_df["parameter_id"] != 570]  # extremely sparse data

# Rename variables and units
par_df["parameter_name"] = par_df["parameter_name"].replace(parameter_name_map)
par_df["unit"] = par_df["unit"].replace(unit_map)

# Save parameters metadata
par_df.to_csv(par_units_fpath, index=False)
par_df
# Out:
# /opt/conda/lib/python3.11/site-packages/nivapy3/da.py:440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stn_df["station_id"].drop_duplicates(inplace=True)
# 123 parameters available for the selected stations and dates.
#      parameter_id   parameter_name     unit
# 35           1539              DOC   mg/l C
# 40            288            Color  mg Pt/l
# 57              8            NH4-N     µg/l
# 59              7            NO3-N     µg/l
# 75             12              TRP     µg/l
# 76            572              POC   µg/l C
# 87            396              SPM     mg/l
# 90           3297               Si     mg/l
# 91            258             SiO2     mg/l
# 94            257              TOC     mg/l
# 95              9             TOTN     µg/l
# 96           4762  TOTN_EF_usikker     µg/l
# 98             11             TOTP     µg/l
# 99            400              TDP   µg/l P
# 100           582               PP   µg/l P
# 102          1241              TSM     mg/l
# 105          3476     UV_Abs_254nm   Abs/cm
# 108          3479     UV_Abs_410nm   Abs/cm

# %% [markdown]
# ## 4. Get water chemistry

# %%
wc_df, dup_df = nivapy.da.select_ndb_water_chemistry(
    sel_stn_df, par_df, st_dt, end_dt, eng, lod_flags=False, drop_dups=True
)

wc_df['station_name'] = wc_df['station_name'].replace('Glomma v/Sarpefossen', 'Glomma, Sarpsfossen') # The station name for Glomma differs between the water chemistry data and the metadata. I rename it here for consistency and to simplify saving and further processing.
# Out:
# /opt/conda/lib/python3.11/site-packages/nivapy3/da.py:729: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stn_df["station_id"].drop_duplicates(inplace=True)
# /opt/conda/lib/python3.11/site-packages/nivapy3/da.py:870: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["parameter_name"].fillna("", inplace=True)
# /opt/conda/lib/python3.11/site-packages/nivapy3/da.py:871: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["unit"].fillna("", inplace=True)

# %%
# Drop irrelevant columns
wc_df = wc_df.drop(columns=cols_to_drop) 

# Split variable names and units
def strip_units(col):
    if col in ['station_id', 'station_code', 'station_name', 'sample_date', 'depth1', 'depth2']:
        return col
    return re.sub(r'_[^_]+$', '', col)

wc_df = wc_df.rename(columns={col: strip_units(col) for col in wc_df.columns})

# Rename specific column to avoid ambiguity 
wc_df = wc_df.rename(columns=parameter_name_map)

wc_df.head()
# Out:
#    station_id station_code  station_name sample_date  DOC  Color  NH4-N  \
#
# 0       40352         DRA1  Drammenselva  1990-01-11  NaN    NaN    NaN
# 1       40352         DRA1  Drammenselva  1990-02-12  NaN    NaN    NaN
# 2       40352         DRA1  Drammenselva  1990-03-13  NaN    NaN    NaN
# 3       40352         DRA1  Drammenselva  1990-04-18  NaN    NaN    NaN
# 4       40352         DRA1  Drammenselva  1990-05-21  NaN    NaN    NaN
#
#    NO3-N  TRP  POC  ...  Si  TOC  TOTN_EF_usikker   TOTN  TDP  PP  TOTP  TSM  \
#                     ...
# 0  235.0  0.5  NaN  ... NaN  NaN              NaN  350.0  NaN NaN   6.0  0.8
# 1  295.0  2.0  NaN  ... NaN  NaN              NaN  419.0  NaN NaN   7.0  2.0
# 2  265.0  1.5  NaN  ... NaN  NaN              NaN  405.0  NaN NaN   6.0  1.4
# 3  270.0  1.5  NaN  ... NaN  NaN              NaN  399.0  NaN NaN   5.0  1.3
# 4  178.0  0.5  NaN  ... NaN  NaN              NaN  317.0  NaN NaN   6.0  1.7
#
#    UV_Abs_254nm  UV_Abs_410nm
#
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 22 columns]

# %%
# Save water chemistry to csv
for full_station_name, simple_river_name in river_mapper.items():
    river_df = wc_df[wc_df['station_name'] == full_station_name]
    
    if not river_df.empty:
        filename = f'water_chem_{simple_river_name}_raw_{today_str}.csv'
        filepath = os.path.join(base_dir, filename)
        river_df.to_csv(filepath, index=False)
        print(f'Saved {filepath}')
    else:
        print(f'No data for station: {full_station_name}')
# Out:
# Saved ../../data/river/water_chemistry/raw/water_chem_Drammenselva_raw_18-06-2025.csv
# Saved ../../data/river/water_chemistry/raw/water_chem_Numedalslagen_raw_18-06-2025.csv
# Saved ../../data/river/water_chemistry/raw/water_chem_Glomma_raw_18-06-2025.csv
